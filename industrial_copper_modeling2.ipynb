# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from sklearn.preprocessing import OrdinalEncoder
# import dataprep.eda.create_report as report
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('copper_Set.csv')
df
# Out:
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0         -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0   406.6865384
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
#check unique value in all columns
df.nunique()
# Out:
# id               181671
# item_date           252
# quantity tons    181673
# customer           1169
# country              17
# status                9
# item type             7
# application          30
# thickness           594
# width              1386
# material_ref      16563
# product_ref          33
# delivery date        28
# selling_price      9795
# dtype: int64

# %%
#check data types of all columns
df.dtypes
# Out:
# id                object
# item_date        float64
# quantity tons     object
# customer         float64
# country          float64
# status            object
# item type         object
# application      float64
# thickness        float64
# width            float64
# material_ref      object
# product_ref        int64
# delivery date    float64
# selling_price    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'material_ref',
#        'product_ref', 'delivery date', 'selling_price'],
#       dtype='object')

# %%
#convert datatypes from object to numeric
df['quantity tons'] = pd.to_numeric(df['quantity tons'], errors='coerce')
df['item_date_1'] = pd.to_datetime(df['item_date'], format='%Y%m%d', errors='coerce').dt.date
df['delivery_date_1'] = pd.to_datetime(df['delivery date'], format='%Y%m%d', errors='coerce').dt.date

# %%
df.dtypes
# Out:
# id                  object
# item_date          float64
# quantity tons      float64
# customer           float64
# country            float64
# status              object
# item type           object
# application        float64
# thickness          float64
# width              float64
# material_ref        object
# product_ref          int64
# delivery date      float64
# selling_price      float64
# item_date_1         object
# delivery_date_1     object
# dtype: object

# %%
df.head(2)
# Out:
#                                      id   item_date  quantity tons  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0      54.151139
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0     768.024839
#
#      customer  country status item type  application  thickness   width  \
# 0  30156308.0     28.0    Won         W         10.0        2.0  1500.0
# 1  30202938.0     25.0    Won         W         41.0        0.8  1210.0
#
#                                material_ref  product_ref  delivery date  \
# 0                               DEQ1 S460MC   1670798778     20210701.0
# 1  0000000000000000000000000000000000104991   1668701718     20210401.0
#
#    selling_price item_date_1 delivery_date_1
# 0          854.0  2021-04-01      2021-07-01
# 1         1047.0  2021-04-01      2021-04-01

# %%
#check null values count
df.isnull().sum()
# Out:
# id                     2
# item_date              1
# quantity tons          1
# customer               1
# country               28
# status                 2
# item type              0
# application           24
# thickness              1
# width                  0
# material_ref       77919
# product_ref            0
# delivery date          1
# selling_price          1
# item_date_1            3
# delivery_date_1        3
# dtype: int64

# %%
# some rubbish value in material_ref col
df['material_ref'] = df['material_ref'].apply(lambda x: np.nan if str(x).startswith('0000') else x)
df.head(5)
# Out:
#                                      id   item_date  quantity tons  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0      54.151139
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0     768.024839
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0     386.127949
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0     202.411065
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0     785.526262
#
#      customer  country status item type  application  thickness   width  \
# 0  30156308.0     28.0    Won         W         10.0       2.00  1500.0
# 1  30202938.0     25.0    Won         W         41.0       0.80  1210.0
# 2  30153963.0     30.0    Won        WI         28.0       0.38   952.0
# 3  30349574.0     32.0    Won         S         59.0       2.30  1317.0
# 4  30211560.0     28.0    Won         W         10.0       4.00  2000.0
#
#               material_ref  product_ref  delivery date  selling_price  \
# ...

# %%
df.isnull().sum()
# Out:
# id                      2
# item_date               1
# quantity tons           1
# customer                1
# country                28
# status                  2
# item type               0
# application            24
# thickness               1
# width                   0
# material_ref       100645
# product_ref             0
# delivery date           1
# selling_price           1
# item_date_1             3
# delivery_date_1         3
# dtype: int64

# %%
#drop cols that have more nan values
df.drop(columns=['id','material_ref'], inplace=True)

# %%
df.head(2)
# Out:
#     item_date  quantity tons    customer  country status item type  \
# 0  20210401.0      54.151139  30156308.0     28.0    Won         W
# 1  20210401.0     768.024839  30202938.0     25.0    Won         W
#
#    application  thickness   width  product_ref  delivery date  selling_price  \
# 0         10.0        2.0  1500.0   1670798778     20210701.0          854.0
# 1         41.0        0.8  1210.0   1668701718     20210401.0         1047.0
#
#   item_date_1 delivery_date_1
# 0  2021-04-01      2021-07-01
# 1  2021-04-01      2021-04-01

# %%
df.describe().T
# Out:
#                   count          mean           std          min  \
# item_date      181672.0  2.020459e+07  4.551119e+03  19950000.00
# quantity tons  181672.0  5.874926e+03  2.349081e+06     -2000.00
# customer       181672.0  3.051221e+07  2.433382e+07     12458.00
# country        181645.0  4.489302e+01  2.440421e+01        25.00
# application    181649.0  2.561581e+01  1.775417e+01         2.00
# thickness      181672.0  2.564827e+00  6.572321e+00         0.18
# width          181673.0  1.295287e+03  2.616318e+02         1.00
# product_ref    181673.0  4.739679e+08  7.175101e+08    611728.00
# delivery date  181672.0  2.020738e+07  2.411059e+04  20190401.00
# selling_price  181672.0  1.918036e+03  3.317956e+05     -1160.00
#
#                         25%           50%           75%           max
# item_date      2.020093e+07  2.020113e+07  2.021020e+07  2.021040e+07
# quantity tons  1.097030e+01  3.036464e+01  6.716061e+01  1.000000e+09
# ...

# %%
#quantiy and selling value are has below 0 , it not should below 0 so convert into 0 to nan
df['quantity tons'] = df['quantity tons'].apply(lambda x: np.nan if x<=0 else x)
df['selling_price'] = df['selling_price'].apply(lambda x: np.nan if x<=0 else x)
df.describe().T
# Out:
#                   count          mean           std           min  \
# item_date      181672.0  2.020459e+07  4.551119e+03  1.995000e+07
# quantity tons  181668.0  5.875066e+03  2.349107e+06  1.000000e-05
# customer       181672.0  3.051221e+07  2.433382e+07  1.245800e+04
# country        181645.0  4.489302e+01  2.440421e+01  2.500000e+01
# application    181649.0  2.561581e+01  1.775417e+01  2.000000e+00
# thickness      181672.0  2.564827e+00  6.572321e+00  1.800000e-01
# width          181673.0  1.295287e+03  2.616318e+02  1.000000e+00
# product_ref    181673.0  4.739679e+08  7.175101e+08  6.117280e+05
# delivery date  181672.0  2.020738e+07  2.411059e+04  2.019040e+07
# selling_price  181665.0  1.918124e+03  3.318020e+05  1.000000e-01
#
#                         25%           50%           75%           max
# item_date      2.020093e+07  2.020113e+07  2.021020e+07  2.021040e+07
# quantity tons  1.097122e+01  3.036501e+01  6.716134e+01  1.000000e+09
# ...

# %%
df.isnull().sum()
# Out:
# item_date           1
# quantity tons       5
# customer            1
# country            28
# status              2
# item type           0
# application        24
# thickness           1
# width               0
# product_ref         0
# delivery date       1
# selling_price       8
# item_date_1         3
# delivery_date_1     3
# dtype: int64

# %%
df.dtypes
# Out:
# item_date          float64
# quantity tons      float64
# customer           float64
# country            float64
# status              object
# item type           object
# application        float64
# thickness          float64
# width              float64
# product_ref          int64
# delivery date      float64
# selling_price      float64
# item_date_1         object
# delivery_date_1     object
# dtype: object

# %%
#handling null values using midean and mode

#object using mode
df['item_date_1'].fillna(df['item_date_1'].mode().iloc[0])
df['item_date'].fillna(df['item_date'].mode().iloc[0])
df['delivery_date_1'].fillna(df['delivery_date_1'].mode().iloc[0])
df['delivery date'].fillna(df['delivery date'].mode().iloc[0])
df['status'].fillna(df['status'].mode().iloc[0])

#numeric use median
df['quantity tons'].fillna(df['quantity tons'].median())
df['customer'].fillna(df['customer'].median())
df['country'].fillna(df['country'].median())
df['application'].fillna(df['application'].median())
df['thickness'].fillna(df['thickness'].median())
df['selling_price'].fillna(df['selling_price'].median())

df.isnull().sum()
# Out:
# item_date           1
# quantity tons       5
# customer            1
# country            28
# status              2
# item type           0
# application        24
# thickness           1
# width               0
# product_ref         0
# delivery date       1
# selling_price       8
# item_date_1         3
# delivery_date_1     3
# dtype: int64

# %%
#find unique values in status
df['status'].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable', nan], dtype=object)

# %%
#find unique values in item type 
df['item type'].unique()
# Out:
# array(['W', 'WI', 'S', 'Others', 'PL', 'IPL', 'SLAWR'], dtype=object)

# %%
# convert catogrical to numeric data
df['status'] = df['status'].map({'Lost':0,'Won':1,'Draft':2,'To be approved':3,'Not lost for AM':4,'Wonderful':5,
                                'Revised':6,'Offered':7,'Offerable':8})
df['item type'] = OrdinalEncoder().fit_transform(df[['item type']])

# %%
df.head(5)
# Out:
#     item_date  quantity tons    customer  country  status  item type  \
# 0  20210401.0      54.151139  30156308.0     28.0     1.0        5.0
# 1  20210401.0     768.024839  30202938.0     25.0     1.0        5.0
# 2  20210401.0     386.127949  30153963.0     30.0     1.0        6.0
# 3  20210401.0     202.411065  30349574.0     32.0     1.0        3.0
# 4  20210401.0     785.526262  30211560.0     28.0     1.0        5.0
#
#    application  thickness   width  product_ref  delivery date  selling_price  \
# 0         10.0       2.00  1500.0   1670798778     20210701.0         854.00
# 1         41.0       0.80  1210.0   1668701718     20210401.0        1047.00
# 2         28.0       0.38   952.0       628377     20210101.0         644.33
# 3         59.0       2.30  1317.0   1668701718     20210101.0         768.00
# 4         10.0       4.00  2000.0       640665     20210301.0         577.00
#
#   item_date_1 delivery_date_1
# 0  2021-04-01      2021-07-01
# ...

# %%
df['item type'].unique()
# Out:
# array([5., 6., 3., 1., 2., 0., 4.])

# %%
df.isnull().sum()
# Out:
# item_date           1
# quantity tons       5
# customer            1
# country            28
# status              2
# item type           0
# application        24
# thickness           1
# width               0
# product_ref         0
# delivery date       1
# selling_price       8
# item_date_1         3
# delivery_date_1     3
# dtype: int64

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# item_date      181672.0  2.020459e+07  4.551119e+03  1.995000e+07
# quantity tons  181668.0  5.875066e+03  2.349107e+06  1.000000e-05
# customer       181672.0  3.051221e+07  2.433382e+07  1.245800e+04
# country        181645.0  4.489302e+01  2.440421e+01  2.500000e+01
# status         181671.0  1.316688e+00  1.330316e+00  0.000000e+00
# item type      181673.0  4.133036e+00  1.055230e+00  0.000000e+00
# application    181649.0  2.561581e+01  1.775417e+01  2.000000e+00
# thickness      181672.0  2.564827e+00  6.572321e+00  1.800000e-01
# width          181673.0  1.295287e+03  2.616318e+02  1.000000e+00
# product_ref    181673.0  4.739679e+08  7.175101e+08  6.117280e+05
# delivery date  181672.0  2.020738e+07  2.411059e+04  2.019040e+07
# selling_price  181665.0  1.918124e+03  3.318020e+05  1.000000e-01
#
#                         25%           50%           75%           max
# ...

# %% [markdown]
# ## Skewness Handling - Feature Scaling (Log Transformation)

# %%
def plot(df,column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=df,x=column)
    plt.title(f'box plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=df,x=column, kde=True, bins=50)
    plt.title(f'distrubtion plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=df,x=column)
    plt.title(f'vilon plot for {column}')
    plt.show()

# %%
for i in ['quantity tons', 'customer', 'country', 'item type', 'application', 'thickness', 'width', 'selling_price']:
    plot(df, i)

# %%
skewed_col = ['quantity tons', 'thickness', 'width', 'selling_price']
for col in skewed_col:
    neg = (df[col] <= 0)
    print(f'{col} : {neg.sum()}')
    df.loc[neg,col] = np.nan
# Out:
# quantity tons : 0
# thickness : 0
# width : 0
# selling_price : 0

# %%
df.isnull().sum()
# Out:
# item_date           1
# quantity tons       5
# customer            1
# country            28
# status              2
# item type           0
# application        24
# thickness           1
# width               0
# product_ref         0
# delivery date       1
# selling_price       8
# item_date_1         3
# delivery_date_1     3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# item_date          0
# quantity tons      0
# customer           0
# country            0
# status             0
# item type          0
# application        0
# thickness          0
# width              0
# product_ref        0
# delivery date      0
# selling_price      0
# item_date_1        0
# delivery_date_1    0
# dtype: int64

# %%
out_skew_data_1=df.drop(['item_date','delivery date','status','item type','item_date_1','delivery_date_1'],axis=1)

# %%
df.skew()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.skew()
#
# File Z:\radhakrishnan\guvi\industrial_copper_modeling\venv\Lib\site-packages\pandas\core\frame.py:11734, in DataFrame.skew(self, axis, skipna, numeric_only, **kwargs)
#   11726 @doc(make_doc("skew", ndim=2))
#   11727 def skew(
#   11728     self,
#    (...)
#   11732     **kwargs,
#   11733 ):
# > 11734     result = super().skew(axis, skipna, numeric_only, **kwargs)
#   11735     if isinstance(result, Series):
#   11736         result = result.__finalize__(self, method="skew")
#
# File Z:\radhakrishnan\guvi\industrial_copper_modeling\venv\Lib\site-packages\pandas\core\generic.py:12435, in NDFrame.skew(self, axis, skipna, numeric_only, **kwargs)
#   12428 def skew(
#   12429     self,
#   12430     axis: Axis | None = 0,
#    (...)
#   12433     **kwargs,
#   12434 ) -> Series | float:
# ...
