# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

# %%
dat = sm.datasets.get_rdataset("Guerry", "HistData").data

# %%
results = smf.ols('Lottery ~ Literacy + np.log(Pop1831)', data=dat).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Lottery   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     22.20
# Date:                Fri, 24 May 2024   Prob (F-statistic):           1.90e-08
# Time:                        10:30:11   Log-Likelihood:                -379.82
# No. Observations:                  86   AIC:                             765.6
# Df Residuals:                      83   BIC:                             773.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## MV_signuture sample data

# %%
qs = {
    'project_id': '123',
    'independent_variable': 'temp,humidity',
    'metersIds': 'meter1,meter2',
    'buildingId': '456'
}
con = pd.DataFrame({
    'fuelType': ['Electricity', 'Electricity', 'Gas', 'Gas'],
    'consumption_raw': [100, 150, 200, 250],
    'project_id': [123, 123, 123, 123],
    'month': ['2023-01', '2023-02', '2023-01', '2023-02']
})
variable = pd.DataFrame({
    'topic': ['temp', 'humidity', 'temp', 'humidity'],
    'value': [25, 60, 30, 65],
    'timestamp': ['2023-01-01', '2023-01-01', '2023-02-01', '2023-02-01']
})

target_y = np.array([100, 150])

# %%
x=sm.add_constant(x)
    model=sm.OLS(y,x)
    results=model.fit()
    adjusted_r_squared=np.round(results.rsquared_adj,2)
    r_squared=np.round(results.rsquared,2)
    y_pred=np.round(results.predict(x),2)
    n=len(y)
    dof=np.sqrt(n/(n-p))
    nmbe=np.round(np.sum(y-y_pred)/((n-p)*np.mean(y)),2)
    cv_rmse=np.round(rmse(y,y_pred)/np.mean(y)*dof,2)
    coef=np.round(results.params,2)
    std=results.bse
    if r_squared>=0.75:
        r_squared_m='The r_squared of the regression model is validated with the standard of ASHRAE Guideline 14 and IPMVP (above 0.75)'
    elif r_squared<0.75 and r_squared>=0.4:
        r_squared_m='The r_squared of the regression model is below the standard of ASHRAE Guideline 14 and IPMVP (below 0.75). Selected independent variables are able to explain part of the consumption variation. Please consider adding other indenpendent variables.'
    else:
        r_squared_m='''The r_squared of the regression model is below the standard of ASHRAE Guideline 14 and IPMVP (below 0.75). Selected independent variables are only able to explain less than 40% of the consumption variation. 
        Please consider other indenpendent variables or double check the validity of your consumption data.'''
    
    if nmbe<0.05:
        nmbe_m='The normalized mean bias error (nmbe) of the regression model is validated with the monthly standard of ASHRAE Guideline 14 (below 5%)'
    else:
        nmbe_m='The normalized mean bias error (nmbe) of the regression model is above the monthly standard of ASHRAE Guideline 14 (above 5%)'

    if cv_rmse<0.15:
        cv_rmse_m='The normalized mean bias error (nmbe) of the regression model is validated with the monthly standard of ASHRAE Guideline 14 (below 15%)'
    else:
        cv_rmse_m='The normalized mean bias error (nmbe) of the regression model is above the monthly standard of ASHRAE Guideline 14 (above 15%)'

    if (y<=0).sum()>3:
        data_m='Please note that there is anomaly detected (missing consumption segments) in your consumption data'
    else:
        data_m='Your data is checked' 
    print(r_squared,adjusted_r_squared,nmbe,cv_rmse,list(results.params.index),list(np.round(results.params.values,2)),r_squared_m,nmbe_m,cv_rmse_m,list(np.round(y_pred,2)),std, data_m)
